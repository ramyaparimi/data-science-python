# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 3)
plt.rcParams['font.family'] = 'sans-serif'

# %%
weather_mar2012 = pd.read_csv('data/weather_2012.csv', skiprows=15, index_col='Date/Time')
weather_mar2012.head()
# Out:
#                   Year  Month  Day   Time  Temp (°C)  Temp Flag  \
# Date/Time
# 2012-03-01 00:00  2012      3    1  00:00       -7.4        NaN
# 2012-03-01 01:00  2012      3    1  01:00       -7.6        NaN
# 2012-03-01 02:00  2012      3    1  02:00       -7.6        NaN
# 2012-03-01 03:00  2012      3    1  03:00       -7.5        NaN
# 2012-03-01 04:00  2012      3    1  04:00       -7.6        NaN
#
#                   Dew Point Temp (°C)  Dew Point Temp Flag  Rel Hum (%)  \
# Date/Time
# 2012-03-01 00:00                -10.9                  NaN           76
# 2012-03-01 01:00                -10.8                  NaN           78
# 2012-03-01 02:00                -10.0                  NaN           83
# 2012-03-01 03:00                 -9.4                  NaN           86
# 2012-03-01 04:00                 -9.2                  NaN           88
#
#                   Rel Hum Flag   ...     Wind Spd Flag  Visibility (km)  \
# Date/Time                        ...
# 2012-03-01 00:00           NaN   ...               NaN              4.8
# 2012-03-01 01:00           NaN   ...               NaN             16.1
# 2012-03-01 02:00           NaN   ...               NaN              8.0
# 2012-03-01 03:00           NaN   ...               NaN              4.8
# 2012-03-01 04:00           NaN   ...               NaN              3.2
#
#                   Visibility Flag  Stn Press (kPa)  Stn Press Flag  Hmdx  \
# Date/Time
# 2012-03-01 00:00              NaN           100.42             NaN   NaN
# 2012-03-01 01:00              NaN           100.34             NaN   NaN
# 2012-03-01 02:00              NaN           100.25             NaN   NaN
# 2012-03-01 03:00              NaN           100.18             NaN   NaN
# 2012-03-01 04:00              NaN           100.09             NaN   NaN
#
#                   Hmdx Flag  Wind Chill  Wind Chill Flag  Weather
# Date/Time
# 2012-03-01 00:00        NaN       -16.0              NaN     Snow
# 2012-03-01 01:00        NaN       -16.0              NaN     Snow
# 2012-03-01 02:00        NaN       -15.0              NaN     Snow
# 2012-03-01 03:00        NaN       -16.0              NaN     Snow
# 2012-03-01 04:00        NaN       -16.0              NaN     Snow
#
# [5 rows x 23 columns]

# %%
weather_mar2012(.plot(figsize=(15,5))
