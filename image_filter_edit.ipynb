# %%
# %matplotlib inline
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
from skimage import data

# %%
photo_data = misc.imread('./new_image.jpg')
plt.figure(figsize=(15,15))
plt.imshow(photo_data)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
print(photo_data.size)
print(photo_data.shape)
# print(photo_data)
# Out:
# 6220800
# (1080, 1920, 3)

# %%
photo_data.min(),photo_data.max()
# Out:
# (0, 255)

# %%
photo_data = misc.imread('./new_image.jpg')
plt.figure(figsize=(15,15))
with_red_filter=photo_data[:500,:,0]=255
plt.imshow(photo_data)
plt.imsave('./red_filter_new_image.jpeg', photo_data)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
photo_data = misc.imread('./new_image.jpg')
plt.figure(figsize=(15,15))
low_filterdata=photo_data<200
photo_data[low_filterdata]=0
plt.imshow(photo_data)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
